# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\tanee\Downloads\archive (19)\student_habits_performance.csv")

# %% [markdown]
# DATASET

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.003971           -0.009151
# study_hours_per_day    0.003971             1.000000            0.020282
# social_media_hours    -0.009151             0.020282            1.000000
# netflix_hours         -0.001174            -0.031158            0.011477
# attendance_percentage -0.026055             0.026264            0.040479
# sleep_hours            0.037482            -0.027757            0.018236
# exercise_frequency    -0.003836            -0.028701           -0.037319
# mental_health_rating  -0.045101            -0.003768            0.001496
# exam_score            -0.008907             0.825419           -0.166733
#
#                        netflix_hours  attendance_percentage  sleep_hours  \
# age                        -0.001174              -0.026055     0.037482
# study_hours_per_day        -0.031158               0.026264    -0.027757
# ...

# %%
df.corr(numeric_only=True)['exam_score']
# Out:
# age                     -0.008907
# study_hours_per_day      0.825419
# social_media_hours      -0.166733
# netflix_hours           -0.171779
# attendance_percentage    0.089836
# sleep_hours              0.121683
# exercise_frequency       0.160107
# mental_health_rating     0.321523
# exam_score               1.000000
# Name: exam_score, dtype: float64

# %% [markdown]
# finding duplicate rows and null values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df[df["parental_education_level"].isna()].shape
# Out:
# (91, 16)

# %%
df['parental_education_level'].fillna('Unknown', inplace=True)

# %%
sns.histplot(data=df, x='study_hours_per_day', bins=10, kde=True, color='purple')
plt.title("Study Hours Distribution")
plt.xlabel("Study Hours")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.histplot(data=df, x='age', bins=8, kde=True, color='purple')
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
sns.histplot(data=df, x='social_media_hours', bins=8, kde=True, color='purple')
plt.title("Social Media Hours Distribution")
plt.xlabel("Social Media Hours")
# Out:
# Text(0.5, 0, 'Social Media Hours')

# %%
sns.histplot(data=df, x='netflix_hours', bins=8, kde=True, color='purple')
plt.title("Netflix Hours Distribution")
plt.xlabel("Netflix Hours")
# Out:
# Text(0.5, 0, 'Netflix Hours')

# %%
sns.histplot(data=df, x='attendance_percentage', bins=8, kde=True, color='purple')
plt.title("Attendance Percentage Distribution")
plt.xlabel("Attendance Percentage")
# Out:
# Text(0.5, 0, 'Attendance Percentage')

# %%
sns.histplot(data=df, x='sleep_hours', bins=8, kde=True, color='purple')
plt.title("Sleep Hours Distribution")
plt.xlabel("Sleep Hours")
# Out:
# Text(0.5, 0, 'Sleep Hours')

# %%
sns.histplot(data=df, x='exercise_frequency', bins=6, kde=True, color='purple')
plt.title('Exercise Frequency Distribution')
plt.xlabel('Exercise Frequency')
len(df[df['exercise_frequency'] >= 3])
# Out:
# 588

# %%
sns.histplot(data=df, x='mental_health_rating', bins=10, kde=True, color='purple')
plt.title('Mental Health Rating Distribution')
plt.xlabel('Mental Health Rating')
# Out:
# Text(0.5, 0, 'Mental Health Rating')

# %%
sns.histplot(data=df, x='exam_score', bins=10, kde=True, color='purple')
plt.title('Exam Score Distribution')
plt.xlabel('Exam Score')
# Out:
# Text(0.5, 0, 'Exam Score')

# %%
sns.countplot(x=df['gender'])
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
sns.countplot(x=df['part_time_job'])
plt.title('Part Time Job Distribution')
plt.xlabel('Part Time Job')
# Out:
# Text(0.5, 0, 'Part Time Job')

# %%
sns.countplot(x=df['diet_quality'])
plt.title('Diet Quality Distribution')
plt.xlabel('Diet Quality')
# Out:
# Text(0.5, 0, 'Diet Quality')

# %%
sns.countplot(x=df['parental_education_level'])
plt.title('Parent Education Level Distribution')
plt.xlabel('Parent Education Level')
# Out:
# Text(0.5, 0, 'Parent Education Level')

# %%
sns.countplot(x=df['internet_quality'])
plt.title('Internet Quality Distribution')
plt.xlabel('Internet Quality')
# Out:
# Text(0.5, 0, 'Internet Quality')

# %%
sns.countplot(x=df['extracurricular_participation'])
plt.title('Extracurricular Participation Distribution')
plt.xlabel('Extracurricular Participation')
# Out:
# Text(0.5, 0, 'Extracurricular Participation')

# %%
len(df[(df['diet_quality'].isin(['Fair', 'Good'])) & (df['exercise_frequency'] >= 3)])
# Out:
# 473

# %%
temp=df[(df['extracurricular_participation']=='No') & (df['part_time_job']=='No') ]
len(temp)
# Out:
# 531

# %%
df['exam_score'].mean()
# Out:
# 69.6015

# %%
temp['exam_score'].mean()
# Out:
# 69.69227871939738

# %%
sns.scatterplot(data=df, x='study_hours_per_day', y='exam_score', color='purple')
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
sns.scatterplot(data=df, x='social_media_hours', y='exam_score', color='purple')
plt.xlabel('Social Media Hours')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
sns.scatterplot(data=df, x='netflix_hours', y='exam_score', color='purple')
plt.xlabel('Netflix Hours')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
sns.scatterplot(data=df, x='attendance_percentage', y='exam_score', color='purple')
plt.xlabel('Attendance Percentage')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
sns.scatterplot(data=df, x='sleep_hours', y='exam_score', color='purple')
plt.xlabel('Sleep Hours')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
sns.boxplot(data=df,x='study_hours_per_day')
plt.xlabel('Study Hours')
# Out:
# Text(0.5, 0, 'Study Hours')

# %%
sns.boxplot(data=df,x='social_media_hours')
plt.xlabel('Social Media Hours')
# Out:
# Text(0.5, 0, 'Social Media Hours')

# %%
sns.boxplot(data=df,x='netflix_hours')
plt.xlabel('Netflix Hours')
# Out:
# Text(0.5, 0, 'Netflix Hours')

# %%
sns.boxplot(data=df,x='attendance_percentage')
plt.xlabel('Attendance Percentage')
# Out:
# Text(0.5, 0, 'Attendance Percentage')

# %%
sns.boxplot(data=df,x='sleep_hours')
plt.xlabel('Sleep Hours')
# Out:
# Text(0.5, 0, 'Sleep Hours')

# %%
sns.boxplot(data=df,x='exam_score')
plt.xlabel('Exam Score')
# Out:
# Text(0.5, 0, 'Exam Score')

# %%
sns.kdeplot(df[(df['internet_quality']=='Good')]['exercise_frequency'],label='Good')
sns.kdeplot(df[(df['internet_quality']=='Average')]['exercise_frequency'],label='Average')
sns.kdeplot(df[(df['internet_quality']=='Poor')]['exercise_frequency'],label='Poor')
plt.xlabel('Exercise Frequency')
plt.legend(title='Internet Quality')

# %%
sns.kdeplot(df[(df['internet_quality']=='Good')]['mental_health_rating'],label='Good')
sns.kdeplot(df[(df['internet_quality']=='Average')]['mental_health_rating'],label='Average')
sns.kdeplot(df[(df['internet_quality']=='Poor')]['mental_health_rating'],label='Poor')
plt.xlabel("Mental Health Rating")
plt.legend(title='Internet Quality')

# %%
sns.kdeplot(df[(df['parental_education_level']=='High School')]['mental_health_rating'],label='HS')
sns.kdeplot(df[(df['parental_education_level']=='Bachelor')]['mental_health_rating'],label='BS')
sns.kdeplot(df[(df['parental_education_level']=='Master')]['mental_health_rating'],label='MS')
plt.xlabel('Mental Health Rating')
plt.legend(title='Parental Education Level')

# %%
sns.barplot(data=df,x='mental_health_rating',y='exam_score')
plt.xlabel('Mental Health Rating')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %% [markdown]
# SUMMARY OF EXPLORATORAY DATA ANALYSIS

# %% [markdown]
# The above dataset displays the data of 1000 students academic performanc(exam score) along with other factors which are:
#
# - student_id
# - age
# - gender
# - study_hours_per_day
# - social_media_hours
# - netflix_hours
# - part_time_job
# - attendance_percentage
# - sleep_hours
# - diet_quality
# - exercise_frequency
# - parental_education_level
# - internet_quality
# - mental_health_rating
# - extracurricular_participation
#
# ------------------------------------------------------------------------------------------------
#
# - *The average class score is 69.6 out of 100*
#
# - *The students age vary from 17 to 24 years. The data is almost evenly distributed among different ages.*
#
# - *On an average the students are spending 3.5 hours on studying, 2.5 for social media, 1.8 for netflix  and 6.8 for sleeping.*
#
# - *More than half of the class(53.7%) is neither involved in extracurricular activities nor doing any part time job suggesting ample amout of time for studies.However despite that the average exam score of this specific group remains closer to the class average*
#
# - *In terms of physical health, majority of students follow fair to good amount of diet and exercise over 3 times a week. Students lying in both of these categories are 47.3% of the total .However the same cannot be commented on the mental health as the rating freuencies are almost evenly distributed*
#
# - *Exam score follows a strong linear relationship with number of study hours. However there are certain outliers present which could be present due to influence of other factors*
#
# - *People with average to poor internet quality are more likely to have higher mental health rating as well as higher exercise frequency than people with good internet quality*
#
# - *Students whose parents education level is masters, are more likely to have a lower mental health rating.*
#
# - *Average exam score of students with better mental health rating is more*

# %%
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...
